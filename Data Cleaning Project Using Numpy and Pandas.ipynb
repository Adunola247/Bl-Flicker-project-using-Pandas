# %% [markdown]
# #### Import Numpy and Pandas Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Import the data file to be cleaned using pandas library

# %%
book = pd.read_csv("BL-Flickr-Images-Book.csv")
book
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %% [markdown]
# #### Check the first 5 entries of the dataset

# %%
book.head(5)
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %% [markdown]
# #### Check the last 5 entries of the dataset

# %%
book.tail(5)
# Out:
#       Identifier Edition Statement Place of Publication Date of Publication  \
# 8282     4158088               NaN               London                1838
# 8283     4158128               NaN                Derby            1831, 32
# 8284     4159563               NaN               London           [1806]-22
# 8285     4159587               NaN  Newcastle upon Tyne                1834
# 8286     4160339               NaN               London             1834-43
#
#                     Publisher  \
# 8282                      NaN
# 8283          M. Mozley & Son
# 8284  T. Cadell and W. Davies
# 8285         Mackenzie & Dent
# 8286                      NaN
#
#                                                   Title  \
# 8282  The Parochial History of Cornwall, founded on,...
# 8283  The History and Gazetteer of the County of Der...
# 8284  Magna Britannia; being a concise topographical...
# 8285  An historical, topographical and descriptive v...
# ...

# %% [markdown]
# #### Check the shape of the dataset

# %%
book.shape
# Out:
# (8287, 15)

# %% [markdown]
# #### Check the information of the dataset

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Identifier              8287 non-null   int64
#  1   Edition Statement       773 non-null    object
#  2   Place of Publication    8287 non-null   object
#  3   Date of Publication     8106 non-null   object
#  4   Publisher               4092 non-null   object
#  5   Title                   8287 non-null   object
#  6   Author                  6509 non-null   object
#  7   Contributors            8287 non-null   object
#  8   Corporate Author        0 non-null      float64
#  9   Corporate Contributors  0 non-null      float64
#  10  Former owner            1 non-null      object
#  11  Engraver                0 non-null      float64
#  12  Issuance type           8287 non-null   object
#  13  Flickr URL              8287 non-null   object
# ...

# %% [markdown]
# #### Drop some columns in the dataset ("Edition Statement", "Corporate Author", "Corporate Contributors", "Former owner", "Engraver", "Contributors", "Issuance type", "Shelfmarks")

# %%
books = book.drop(columns=["Edition Statement", "Corporate Author", "Corporate Contributors", "Former owner", "Engraver", "Contributors", "Issuance type", "Shelfmarks"])

# %% [markdown]
# #### Check the description of the new formed data

# %%
books.describe()
# Out:
#          Identifier
# count  8.287000e+03
# mean   2.017344e+06
# std    1.190379e+06
# min    2.060000e+02
# 25%    9.157875e+05
# 50%    2.043707e+06
# 75%    3.047430e+06
# max    4.160339e+06

# %% [markdown]
# #### Check the first five entries of the  new formed dataset

# %%
books.head(5)
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                         Flickr URL
# 0      A. A.  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %% [markdown]
# #### Check the last five entries of the  new formed dataset

# %%
books.tail(5)
# Out:
#       Identifier Place of Publication Date of Publication  \
# 8282     4158088               London                1838
# 8283     4158128                Derby            1831, 32
# 8284     4159563               London           [1806]-22
# 8285     4159587  Newcastle upon Tyne                1834
# 8286     4160339               London             1834-43
#
#                     Publisher  \
# 8282                      NaN
# 8283          M. Mozley & Son
# 8284  T. Cadell and W. Davies
# 8285         Mackenzie & Dent
# 8286                      NaN
#
#                                                   Title  \
# 8282  The Parochial History of Cornwall, founded on,...
# 8283  The History and Gazetteer of the County of Der...
# 8284  Magna Britannia; being a concise topographical...
# 8285  An historical, topographical and descriptive v...
# 8286  Collectanea Topographica et Genealogica. [Firs...
#
#                                                  Author  \
# ...

# %% [markdown]
# #### set the "Identifier" column as the index of the dataset

# %%
boo_k = books.set_index("Identifier")

# %% [markdown]
# #### Check the first five entries of the dataset again

# %%
boo_k.head(5)
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %% [markdown]
# #### Check the columns present in the dataset

# %%
boo_k.columns
# Out:
# Index(['Place of Publication', 'Date of Publication', 'Publisher', 'Title',
#        'Author', 'Flickr URL'],
#       dtype='object')

# %% [markdown]
# #### View the data present in the column "Place of Publication"

# %%
boo_k["Place of Publication"]
# Out:
# Identifier
# 206                          London
# 216        London; Virtue & Yorston
# 218                          London
# 472                          London
# 480                          London
#                      ...
# 4158088                      London
# 4158128                       Derby
# 4159563                      London
# 4159587         Newcastle upon Tyne
# 4160339                      London
# Name: Place of Publication, Length: 8287, dtype: object

# %%
#### View the data present in the column "Date of Publication"

# %%
boo_k["Date of Publication"]
# Out:
# Identifier
# 206        1879 [1878]
# 216               1868
# 218               1869
# 472               1851
# 480               1857
#               ...
# 4158088           1838
# 4158128       1831, 32
# 4159563      [1806]-22
# 4159587           1834
# 4160339        1834-43
# Name: Date of Publication, Length: 8287, dtype: object

# %% [markdown]
# #### View the data present in the first column using the "iloc" function

# %%
boo_k.iloc[:,0]
# Out:
# Identifier
# 206                          London
# 216        London; Virtue & Yorston
# 218                          London
# 472                          London
# 480                          London
#                      ...
# 4158088                      London
# 4158128                       Derby
# 4159563                      London
# 4159587         Newcastle upon Tyne
# 4160339                      London
# Name: Place of Publication, Length: 8287, dtype: object

# %% [markdown]
# #### View the first three entries data present in the first column using the "iloc" function

# %%
boo_k.iloc[[0,1,2],0]
# Out:
# Identifier
# 206                      London
# 216    London; Virtue & Yorston
# 218                      London
# Name: Place of Publication, dtype: object

# %% [markdown]
# #### Check the type of the dataframe

# %%
type(boo_k)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Using the "loc" function, return few entries from the "Place of Publication" and "Title" fields.

# %%
place_title = boo_k.loc[206:480, ["Place of Publication", "Title"]]
place_title
# Out:
#                 Place of Publication  \
# Identifier
# 206                           London
# 216         London; Virtue & Yorston
# 218                           London
# 472                           London
# 480                           London
#
#                                                         Title
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A
# 216         All for Greed. [A novel. The dedication signed...
# 218         Love the Avenger. By the author of “All for Gr...
# 472         Welsh Sketches, chiefly ecclesiastical, to the...
# 480         [The World in which I live, and my place in it...

# %% [markdown]
# #### View the datatype contained in all the fields of the dataset

# %%
boo_k.dtypes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Place of Publication    object
# Date of Publication     object
# Publisher               object
# Title                   object
# Author                  object
# Flickr URL              object
# dtype: object>

# %% [markdown]
# #### Using the "loc" function return the data present in the "Date of Publication" field in "1905" index.

# %%
boo_k.loc[1905, ["Date of Publication"]]
# Out:
# Date of Publication    1888
# Name: 1905, dtype: object

# %%
extr = boo_k['Date of Publication'].str.extract(r'^(\d{4})', expand=False)

# %%
boo_k
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
# ...                              ...                 ...
# 4158088                       London                1838
# 4158128                        Derby            1831, 32
# 4159563                       London           [1806]-22
# 4159587          Newcastle upon Tyne                1834
# 4160339                       London             1834-43
#
#                           Publisher  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...

# %% [markdown]
# #### Convert the column "Date of publication" to numeric data

# %%
boo_k['Date of Publication'] = pd.to_numeric(extr)

# %% [markdown]
# #### Check the datatype of the column

# %%
boo_k['Date of Publication'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Inspect the entries present in the dataset

# %%
boo_k
# Out:
#                 Place of Publication  Date of Publication  \
# Identifier
# 206                           London               1879.0
# 216         London; Virtue & Yorston               1868.0
# 218                           London               1869.0
# 472                           London               1851.0
# 480                           London               1857.0
# ...                              ...                  ...
# 4158088                       London               1838.0
# 4158128                        Derby               1831.0
# 4159563                       London                  NaN
# 4159587          Newcastle upon Tyne               1834.0
# 4160339                       London               1834.0
#
#                           Publisher  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...
